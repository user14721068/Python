# %% [markdown]
# # **Introduction to Data Visualization with Seaborn**

# %% [markdown]
# Course Description
#
#
# Seaborn is a powerful Python library that makes it easy to create informative and attractive visualizations. This course provides an introduction to Seaborn and teaches you how to visualize your data using plots such as scatter plots, box plots, and bar plots. You’ll do this while exploring survey responses about student hobbies and the factors that are associated with academic success. You’ll also learn about some of Seaborn’s advantages as a statistical visualization tool, such as how it automatically calculates confidence intervals. By the end of the course, you will be able to use Seaborn in a variety of situations to explore your data and effectively communicate the results of your data analyses to others.

# %% [markdown]
# ## **Chapter 1.-Introduction to Seaborn**

# %% [markdown]
# What is Seaborn, and when should you use it? In this chapter, you will find out! Plus, you will learn how to create scatter plots and count plots with both lists of data and pandas DataFrames. You will also be introduced to one of the big advantages of using Seaborn - the ability to easily add a third variable to your plots by using color to represent different subgroups.

# %% [markdown]
# **Introduction to Seaborn(VIDEO)**
#
# **Making a scatter plot with lists**
#
# **Making a count plot with a list**
#
# **Using pandas with Seaborn(VIDEO)**
#
# **"Tidy" vs. "untidy" data**
#
# **Making a count plot with a DataFrame**
#
# **Adding a third variable with hue(VIDEO)**
#
# **Hue and scatter plots**
#
# **Hue and count plots**

# %% [markdown]
# ### **Introduction to Seaborn(VIDEO)**

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

height = [62,64,69,75,66,68,65,71,76,73]
weight = [62,64,69,75,66,68,65,71,76,73]
sns.scatterplot(x=height,y=weight)
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

gender = ["female","female","female","female","male","male","male","male","male","male"]
sns.countplot(x=gender)
plt.show()

# %% [markdown]
# ### **Making a scatter plot with lists**

# %% [markdown]
# Making a scatter plot with lists
# In this exercise, we'll use a dataset that contains information about 227 countries. This dataset has lots of interesting information on each country, such as the country's birth rates, death rates, and its gross domestic product (GDP). GDP is the value of all the goods and services produced in a year, expressed as dollars per person.
#
# We've created three lists of data from this dataset to get you started. gdp is a list that contains the value of GDP per country, expressed as dollars per person. phones is a list of the number of mobile phones per 1,000 people in that country. Finally, percent_literate is a list that contains the percent of each country's population that can read and write.

# %%
# Instructions 1/4
# Import Matplotlib and Seaborn using the standard naming convention.
# Instructions 2/4
# Create a scatter plot of GDP (gdp) vs. number of phones per 1000 people (phones).
# Instructions 3/4
# Display the plot.
# Instructions 4/4
# Change the scatter plot so it displays the percent of the population that can read and write (percent_literate) on the y-axis.

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

gdp = pd.read_excel("gdp.xlsx")
gdp = list(gdp.values.ravel())                                                  #Cargar las listas

phones = pd.read_excel("phones.xlsx")
phones = list(phones.values.ravel())                                            #Cargar las listas

percent_literate = pd.read_excel("percent_literate.xlsx")
percent_literate = list(percent_literate.values.ravel())                        #Cargar las listas

sns.scatterplot(x=gdp,y=phones) 
plt.show()

sns.scatterplot(x=gdp,y=percent_literate)
plt.show()

# %% [markdown]
# Alright! While this plot does not show a linear relationship between GDP and percent literate, countries with a lower GDP do seem more likely to have a lower percent of the population that can read and write.

# %% [markdown]
# ### **Making a count plot with a list**

# %% [markdown]
# In the last exercise, we explored a dataset that contains information about 227 countries. Let's do more exploration of this data - specifically, how many countries are in each region of the world?
#
# To do this, we'll need to use a count plot. Count plots take in a categorical list and return bars that represent the number of list entries per category. You can create one here using a list of regions for each country, which is a variable named region.

# %%
# Instructions
# 100 XP
# Import Matplotlib and Seaborn using the standard naming conventions.
# Use Seaborn to create a count plot with region on the y-axis.
# Display the plot.

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

region = pd.read_excel("region.xlsx")
display(region)
region = list(region.values.ravel())

sns.countplot(y=region)
plt.show()
# Out:
#                    region
# 0    ASIA (EX. NEAR EAST)
# 1          EASTERN EUROPE
# 2         NORTHERN AFRICA
# 3                 OCEANIA
# 4          WESTERN EUROPE
# ..                    ...
# 222             NEAR EAST
# 223       NORTHERN AFRICA
# 224             NEAR EAST
# 225    SUB-SAHARAN AFRICA
# 226    SUB-SAHARAN AFRICA
#
# [227 rows x 1 columns]

# %% [markdown]
# ### **Using pandas with Seaborn(VIDEO)**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("masculinity.xlsx")
display(df)

sns.countplot(x="how_masculine",data=df)
plt.show()
# Out:
#    participant_id    age   how_masculine how_important
# 0               1  18-34        somewhat      somewhat
# 1               2  18-34        somewhat      somewhat
# 2               3  18-34        somewhat      not_very
# 3               4  18-34  very_important      not_very
# 4               5  18-34  very_important          very

# %% [markdown]
# ### **"Tidy" vs. "untidy" data**

# %% [markdown]
# Here, we have a sample dataset from a survey of children about their favorite animals. But can we use this dataset as-is with Seaborn? Let's use pandas to import the csv file with the data collected from the survey and determine whether it is tidy, which is essential to having it work well with Seaborn.
#
# To get you started, the filepath to the csv file has been assigned to the variable csv_filepath.
#
# Note that because csv_filepath is a Python variable, you will not need to put quotation marks around it when you read the csv.

# %%
# Instructions 1/2
# 50 XP
# Read the csv file located at csv_filepath into a DataFrame named df.
# Print the head of df to show the first five rows.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

df = pd.read_excel("animals.xlsx")
display(df)
# Out:
#    Unnamed: 0               How old are you?
# 0      Marion                             12
# 1       Elroy                             16
# 2         NaN  What is your favorite animal?
# 3      Marion                            dog
# 4       Elroy                            cat
# 5         NaN                            NaN
# 6         NaN                            NaN
# 7         NaN                            NaN
# 8         NaN                            NaN
# 9         NaN                            NaN
# 10        NaN                            NaN
# 11        NaN                            NaN
# 12        NaN                            NaN
# 13        NaN                            NaN
# 14        NaN                            NaN
# 15        NaN                            NaN
# 16        NaN                            NaN

# %%
# Instructions 2/2
# 50 XP
# Question
# View the first five rows of the DataFrame df. Is it tidy? Why or why not?
# Possible Answers
#       Yes, because there are no typos or missing values.
#       Yes, because it is well organized and easy to read.
#       No, because a single column contains different types of information.

# Respuesta: No, because a single column contains different types of information.

# %% [markdown]
# ### **Making a count plot with a DataFrame**

# %% [markdown]
# In this exercise, we'll look at the responses to a survey sent out to young people. Our primary question here is: how many young people surveyed report being scared of spiders? Survey participants were asked to agree or disagree with the statement "I am afraid of spiders". Responses vary from 1 to 5, where 1 is "Strongly disagree" and 5 is "Strongly agree".
#
# To get you started, the filepath to the csv file with the survey data has been assigned to the variable csv_filepath.
#
# Note that because csv_filepath is a Python variable, you will not need to put quotation marks around it when you read the csv.

# %%
# Instructions
# 100 XP
# Import Matplotlib, pandas, and Seaborn using the standard names.
# Create a DataFrame named df from the csv file located at csv_filepath.
# Use the countplot() function with the x= and data= arguments to create a count plot with the "Spiders" column values on the x-axis.
# Display the plot.

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("spiders.xlsx")
display(df)
sns.countplot(x="Spiders",data=df)
plt.show()
# Out:
#       index  Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  \
# 0         0           0    5.0     1.0     5.0      1.0          3.0   4.0
# 1         1           1    4.0     1.0     5.0      1.0          5.0   5.0
# 2         2           2    5.0     1.0     5.0      1.0          5.0   5.0
# 3         3           3    5.0     2.0     5.0      4.0          4.0   1.0
# 4         4           4    5.0     2.0     5.0      3.0          2.0   1.0
# ...     ...         ...    ...     ...     ...      ...          ...   ...
# 1005   1005        1005    5.0     3.0     5.0      4.0          1.0   4.0
# 1006   1006        1006    4.0     4.0     5.0      4.0          5.0   5.0
# 1007   1007        1007    4.0     1.0     4.0      2.0          3.0   5.0
# 1008   1008        1008    5.0     2.0     5.0      3.0          1.0   4.0
# 1009   1009        1009    5.0     3.0     5.0      2.0          2.0   5.0
#
#       Spiders  Loneliness  Parents' advice           Internet usage  Finances  \
# 0         1.0         3.0              4.0          few hours a day       3.0
# 1         1.0         2.0              2.0          few hours a day       3.0
# 2         1.0         5.0              3.0          few hours a day       2.0
# 3         5.0         5.0              2.0          most of the day       2.0
# 4         1.0         3.0              3.0          few hours a day       4.0
# ...       ...         ...              ...                      ...       ...
# 1005      2.0         4.0              4.0          few hours a day       3.0
# 1006      1.0         1.0              4.0  less than an hour a day       3.0
# 1007      2.0         4.0              4.0          most of the day       1.0
# 1008      3.0         3.0              3.0          most of the day       3.0
# 1009      1.0         3.0              3.0          few hours a day       5.0
#
#      Age Siblings  Gender Village - town
# 0     20        1  female        village
# 1     19        2  female           city
# 2     20        2  female           city
# 3     22        1  female           city
# 4     20        1  female        village
# ...   ..      ...     ...            ...
# 1005  20        1  female           city
# 1006  27        5    male        village
# 1007  18        0  female           city
# 1008  25        1  female           city
# 1009  21        1    male        village
#
# [1010 rows x 17 columns]

# %% [markdown]
# ### **Adding a third variable with hue**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset("tips")
display(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x="total_bill",y="tip",data=df)                                             #Scatterplot con "total_bill" y "tip"
plt.show()

# %%
sns.scatterplot(x="total_bill",y="tip",data=df,hue="smoker")                                #Agregar color con la variable "smoker"
plt.show()

# %%
sns.scatterplot(x="total_bill",y="tip",data=df,hue="smoker",hue_order=["No","Yes"])         #Seleccionar el orden de color de la variable smoker
plt.show()

# %%
diccionario = {"Yes":"Black",                                                               #Usando un diccionario de colores
               "No":"Red"}
sns.scatterplot(x="total_bill",y="tip",data=df,hue="smoker",palette=diccionario)
plt.show()

# %%
diccionario = {"Yes":"#808080",                                                               #Usando un diccionario con nombres de colores html
               "No":"#00FF00"}
sns.scatterplot(x="total_bill",y="tip",data=df,hue="smoker",palette=diccionario)
plt.show()

# %%
diccionario = {"Male":"#7BD9B2",                                                               #Usando un diccionario con nombres de colores html con un grafico de barras
               "Female":"#FFDD33"}
sns.countplot(x="smoker",data=df,hue="sex",palette=diccionario)
plt.show()

# %% [markdown]
# ### **Hue and scatter plots**

# %% [markdown]
# In the prior video, we learned how hue allows us to easily make subgroups within Seaborn plots. Let's try it out by exploring data from students in secondary school. We have a lot of information about each student like their age, where they live, their study habits and their extracurricular activities.
#
# For now, we'll look at the relationship between the number of absences they have in school and their final grade in the course, segmented by where the student lives (rural vs. urban area).

# %%
# Instructions 1/2
# 50 XP
# Create a scatter plot with "absences" on the x-axis and final grade ("G3") on the y-axis using the DataFrame student_data. 
# Color the plot points based on "location" (urban vs. rural).

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

student_data = pd.read_excel("student_data.xlsx")
display(student_data.head(5))

sns.scatterplot(x="absences",y="G3",data=student_data,hue="location")
plt.show()
# Out:
#    index school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  \
# 0      0     GP   F   18     GT3       A     4     4           2         0
# 1      1     GP   F   17     GT3       T     1     1           1         0
# 2      2     GP   F   15     LE3       T     1     1           1         3
# 3      3     GP   F   15     GT3       T     4     2           1         0
# 4      4     GP   F   16     GT3       T     3     3           1         0
#
#    ... goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0  ...     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1  ...     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# 2  ...     2    2    3      3       10   7   8  10     Urban   2 to 5 hours
# 3  ...     2    1    1      5        2  15  14  15     Urban  5 to 10 hours
# 4  ...     2    1    2      5        4   6  10  10     Urban   2 to 5 hours
#
# [5 rows x 30 columns]

# %%
# Instructions 2/2
# 50 XP
# Make "Rural" appear before "Urban" in the plot legend.

sns.scatterplot(x="absences",y="G3",data=student_data,hue="location",hue_order=["Rural","Urban"])
plt.show()

# %% [markdown]
# ### **Hue and count plots**

# %% [markdown]
# Let's continue exploring our dataset from students in secondary school by looking at a new variable. The "school" column indicates the initials of which school the student attended - either "GP" or "MS".
#
# In the last exercise, we created a scatter plot where the plot points were colored based on whether the student lived in an urban or rural area. How many students live in urban vs. rural areas, and does this vary based on what school the student attends? Let's make a count plot with subgroups to find out.

# %%
diccionario = {"Rural":"Orange",
               "Urban":"Red"}
sns.countplot(x="school",data=student_data,hue="location",palette=diccionario)
plt.show()

# %% [markdown]
# ## **Chapter 2.-Visualizing Two Quantitative Variables**

# %% [markdown]
# In this chapter, you will create and customize plots that visualize the relationship between two quantitative variables. To do this, you will use scatter plots and line plots to explore how the level of air pollution in a city changes over the course of a day and how horsepower relates to fuel efficiency in cars. You will also see another big advantage of using Seaborn - the ability to easily create subplots in a single figure!

# %% [markdown]
# **Introduction to relational plots and subplots(VIDEO)**
#
# **Creating subplots with col and row**
#
# **Creating two-factor subplots**
#
# **Customizing scatter plots(VIDEO)**
#
# **Changing the size of scatter plot points**
#
# **Changing the style of scatter plot points**
#
# **Introduction to line plots(VIDEO)**
#
# **Interpreting line plots**
#
# **Visualizing standard deviation with line plots**
#
# **Plotting subgroups in line plots**

# %% [markdown]
# ### **Introduction to relational plots and subplots(VIDEO)**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")
display(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill",y="tip",data=df,kind="scatter",col="smoker")                             #Subplot en columnas
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=df,kind="scatter",row="smoker")                                           #Subplot en filas
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=df,kind="scatter",col="smoker",row="time")                                 #Subplot en filas y columnas
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=df,kind="scatter",col="day",col_wrap=3)                                    #Subplot en columnas especificando cuantas graficas por columna se desean (wrap)
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=df,kind="scatter",col="day",col_wrap=3,col_order=["Sun","Sat","Fri","Thur"])                    #Definir el orden de las graficas con col_order
plt.show()

# %% [markdown]
# ### **Creating subplots with col and row**

# %% [markdown]
# We've seen in prior exercises that students with more absences ("absences") tend to have lower final grades ("G3"). Does this relationship hold regardless of how much time students study each week?
#
# To answer this, we'll look at the relationship between the number of absences that a student has in school and their final grade in the course, creating separate subplots based on each student's weekly study time ("study_time").
#
# Seaborn has been imported as sns and matplotlib.pyplot has been imported as plt.

# %%
# Instructions 1/3
# 35 XP
# Modify the code to use relplot() instead of scatterplot()

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

student_data = pd.read_excel("student_data.xlsx")
display(student_data)

sns.relplot(x="absences",y="G3",data=student_data,kind="scatter")
plt.show()
# Out:
#      index school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  \
# 0        0     GP   F   18     GT3       A     4     4           2         0
# 1        1     GP   F   17     GT3       T     1     1           1         0
# 2        2     GP   F   15     LE3       T     1     1           1         3
# 3        3     GP   F   15     GT3       T     4     2           1         0
# 4        4     GP   F   16     GT3       T     3     3           1         0
# ..     ...    ...  ..  ...     ...     ...   ...   ...         ...       ...
# 390    390     MS   M   20     LE3       A     2     2           1         2
# 391    391     MS   M   17     LE3       T     3     1           2         0
# 392    392     MS   M   21     GT3       T     1     1           1         3
# 393    393     MS   M   18     LE3       T     3     2           3         0
# 394    394     MS   M   19     LE3       T     1     1           1         0
#
#      ... goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0    ...     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1    ...     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# 2    ...     2    2    3      3       10   7   8  10     Urban   2 to 5 hours
# 3    ...     2    1    1      5        2  15  14  15     Urban  5 to 10 hours
# 4    ...     2    1    2      5        4   6  10  10     Urban   2 to 5 hours
# ..   ...   ...  ...  ...    ...      ...  ..  ..  ..       ...            ...
# 390  ...     4    4    5      4       11   9   9   9     Urban   2 to 5 hours
# 391  ...     5    3    4      2        3  14  16  16     Urban       <2 hours
# 392  ...     3    3    3      3        3  10   8   7     Rural       <2 hours
# 393  ...     1    3    4      5        0  11  12  10     Rural       <2 hours
# 394  ...     3    3    3      5        5   8   9   9     Urban       <2 hours
#
# [395 rows x 30 columns]

# %%
# Instructions 2/3
# 35 XP
# Modify the code to create one scatter plot for each level of the variable "study_time", arranged in columns.

sns.relplot(x="absences",y="G3",data=student_data,kind="scatter",col="study_time")
plt.show()

# %%
# Instructions 3/3
# 30 XP
# Adapt your code to create one scatter plot for each level of a student's weekly study time, this time arranged in rows.

sns.relplot(x="absences",y="G3",data=student_data,kind="scatter",row="study_time")
plt.show()

# %% [markdown]
# ### **Creating two-factor subplots**

# %% [markdown]
# Let's continue looking at the student_data dataset of students in secondary school. Here, we want to answer the following question: does a student's first semester grade ("G1") tend to correlate with their final grade ("G3")?
#
# There are many aspects of a student's life that could result in a higher or lower final grade in the class. For example, some students receive extra educational support from their school ("schoolsup") or from their family ("famsup"), which could result in higher grades. Let's try to control for these two factors by creating subplots based on whether the student received extra educational support from their school or family.
#
# Seaborn has been imported as sns and matplotlib.pyplot has been imported as plt.

# %%
# Instructions 1/3
# 35 XP
# Use relplot() to create a scatter plot with "G1" on the x-axis and "G3" on the y-axis, using the student_data DataFrame.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

student_data = pd.read_excel("student_data.xlsx")
display(student_data)

sns.relplot(x="G1",y="G3",data=student_data,kind="scatter")
plt.show()
# Out:
#      index school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  \
# 0        0     GP   F   18     GT3       A     4     4           2         0
# 1        1     GP   F   17     GT3       T     1     1           1         0
# 2        2     GP   F   15     LE3       T     1     1           1         3
# 3        3     GP   F   15     GT3       T     4     2           1         0
# 4        4     GP   F   16     GT3       T     3     3           1         0
# ..     ...    ...  ..  ...     ...     ...   ...   ...         ...       ...
# 390    390     MS   M   20     LE3       A     2     2           1         2
# 391    391     MS   M   17     LE3       T     3     1           2         0
# 392    392     MS   M   21     GT3       T     1     1           1         3
# 393    393     MS   M   18     LE3       T     3     2           3         0
# 394    394     MS   M   19     LE3       T     1     1           1         0
#
#      ... goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0    ...     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1    ...     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# 2    ...     2    2    3      3       10   7   8  10     Urban   2 to 5 hours
# 3    ...     2    1    1      5        2  15  14  15     Urban  5 to 10 hours
# 4    ...     2    1    2      5        4   6  10  10     Urban   2 to 5 hours
# ..   ...   ...  ...  ...    ...      ...  ..  ..  ..       ...            ...
# 390  ...     4    4    5      4       11   9   9   9     Urban   2 to 5 hours
# 391  ...     5    3    4      2        3  14  16  16     Urban       <2 hours
# 392  ...     3    3    3      3        3  10   8   7     Rural       <2 hours
# 393  ...     1    3    4      5        0  11  12  10     Rural       <2 hours
# 394  ...     3    3    3      5        5   8   9   9     Urban       <2 hours
#
# [395 rows x 30 columns]

# %%
# Instructions 2/3
# 35 XP
# Create column subplots based on whether the student received support from the school ("schoolsup"), ordered so that "yes" comes before "no".

sns.relplot(x="G1",y="G3",data=student_data,kind="scatter",col="schoolsup",col_order=["yes","no"])
plt.show()

# %%
# Instructions 3/3
# 30 XP
# Add row subplots based on whether the student received support from the family ("famsup"), ordered so that "yes" comes before "no". This will result in subplots based on two factors.

sns.relplot(x="G1",y="G3",data=student_data,kind="scatter",col="schoolsup",col_order=["yes","no"],row="famsup",row_order=["yes","no"])
plt.show()

# %% [markdown]
# ### **Customizing scatter plots(VIDEO)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")
display(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill",y="tip",data=df,kind="scatter",size="size")                #Parametro size para indicar el tamaño de los puntos
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=df,kind="scatter",size="size",hue="size")     #Parametro size y hue para visualizar una tercera variable
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=df,kind="scatter",hue="smoker",style="smoker")  #Parametro "style" para elegir el tipo de punto
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=df,kind="scatter",alpha=0.3)                     #Parametro "alpha" para definir la transparencia
plt.show()

# %% [markdown]
# ### **Changing the size of scatter plot points**

# %% [markdown]
# In this exercise, we'll explore Seaborn's mpg dataset, which contains one row per car model and includes information such as the year the car was made, the number of miles per gallon ("M.P.G.") it achieves, the power of its engine (measured in "horsepower"), and its country of origin.
#
# What is the relationship between the power of a car's engine ("horsepower") and its fuel efficiency ("mpg")? And how does this relationship vary by the number of cylinders ("cylinders") the car has? Let's find out.
#
# Let's continue to use relplot() instead of scatterplot() since it offers more flexibility.

# %%
# Instructions 1/2
# 50 XP
# Use relplot() and the mpg DataFrame to create a scatter plot with "horsepower" on the x-axis and "mpg" on the y-axis. 
# Vary the size of the points by the number of cylinders in the car ("cylinders").

import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("mpg")
display(df.head(5))

sns.relplot(x="horsepower",y="mpg",data=df,kind="scatter",size="cylinders")
plt.show()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# Instructions 2/2
# 50 XP
# To make this plot easier to read, use hue to vary the color of the points by the number of cylinders in the car ("cylinders").

sns.relplot(x="horsepower",y="mpg",data=df,kind="scatter",size="cylinders",hue="cylinders")
plt.show()

# %% [markdown]
# ### **Changing the style of scatter plot points**

# %% [markdown]
# Let's continue exploring Seaborn's mpg dataset by looking at the relationship between how fast a car can accelerate ("acceleration") and its fuel efficiency ("mpg"). Do these properties vary by country of origin ("origin")?
#
# Note that the "acceleration" variable is the time to accelerate from 0 to 60 miles per hour, in seconds. Higher values indicate slower acceleration.

# %%
# Instructions
# 100 XP
# Use relplot() and the mpg DataFrame to create a scatter plot with "acceleration" on the x-axis and "mpg" on the y-axis. 
# Vary the style and color of the plot points by country of origin ("origin").

import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("mpg")

sns.relplot(x="acceleration",y="mpg",data=df,kind="scatter",hue="origin",style="origin")
plt.show()

# %% [markdown]
# ### **Introduction to line plots(VIDEO)**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("air_pollution.xlsx")
display(df.head(5))

sns.relplot(x="hour",y="NO_2_mean",data=df,kind="line")                         #Argumento "kind" para crear un grafico de linea
plt.show()
# Out:
#    hour  NO_2_mean
# 0     1         19
# 1     2         11
# 2     3         21
# 3     4         24
# 4     5         19

# %%
df = pd.read_excel("air_pollution_by_location.xlsx")
display(df.head(5))

sns.relplot(x="hour",y="NO_2_mean",data=df,kind="line",hue="location",style="location",markers=True)  #Argumentos hue, style, markers
plt.show()                                                                                            #para mostrar subgrupos con una observacion
                                                                                                      #al tiempo t
# Out:
#    hour location  NO_2_mean
# 0     1    Norte         32
# 1     1      Sur         25
# 2     2    Norte         33
# 3     2      Sur         29
# 4     3    Norte         28

# %%
df = pd.read_excel("air_pollution_by_location_multiple.xlsx")
display(df.head(5))

sns.relplot(x="hour",y="NO_2_mean",data=df,kind="line")                                                 #Grafica de un unico grupo que tiene multiples observaciones en cada tiempo t
plt.show()                                                                                              #La linea solida muestra la media y la banda un intervalo de confianza para la media
# Out:
#    hour  NO_2_mean     station location
# 0     1         21  Estacion 1      Sur
# 1     2         27  Estacion 1      Sur
# 2     3         13  Estacion 1      Sur
# 3     4         23  Estacion 1      Sur
# 4     5         17  Estacion 1      Sur

# %%
sns.relplot(x="hour",y="NO_2_mean",data=df,kind="line",ci="sd")                                         #Grafica de un unico grupo que tiene multiples observaciones en cada tiempo t
plt.show()                                                                                              #La linea solida muestra la media y en las bandas la Desviacion Estandar

# %%
sns.relplot(x="hour",y="NO_2_mean",data=df,kind="line",ci=None)                                         #Grafica de un unico grupo que tiene multiples observaciones en cada tiempo t
plt.show()

# %% [markdown]
# ### **Interpreting line plots**

# %% [markdown]
# Interpreting line plots
# In this exercise, we'll continue to explore Seaborn's mpg dataset, which contains one row per car model and includes information such as the year the car was made, its fuel efficiency (measured in "miles per gallon" or "M.P.G"), and its country of origin (USA, Europe, or Japan).
#
# How has the average miles per gallon achieved by these cars changed over time? Let's use line plots to find out!

# %%
# Instructions 1/2
# 50 XP
# Use relplot() and the mpg DataFrame to create a line plot with "model_year" on the x-axis and "mpg" on the y-axis.

import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("mpg")
display(df.head(5))

sns.relplot(x="model_year",y="mpg",data=df,kind="line")                         # The shaded region represents a confidence interval for the mean, not the distribution of the observations.
plt.show()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# Instructions 2/2
# 50 XP
# Question
# Which of the following is NOT a correct interpretation of this line plot?
# Possible Answers:
# The average miles per gallon has generally increased over time.
# The distribution of miles per gallon is smaller in 1973 compared to 1977.
# The 95% confidence interval for average miles per gallon in 1970 is approximately 16 - 19.5 miles per gallon.
# This plot assumes that our data is a random sample of all cars in the US, Europe, and Japan.

# Respuesta:  The distribution of miles per gallon is smaller in 1973 compared to 1977. 
# The shaded region represents a confidence interval for the mean, not the distribution of the observations.

# %% [markdown]
# ### **Visualizing standard deviation with line plots**

# %% [markdown]
# In the last exercise, we looked at how the average miles per gallon achieved by cars has changed over time. Now let's use a line plot to visualize how the distribution of miles per gallon has changed over time.
#
# Seaborn has been imported as sns and matplotlib.pyplot has been imported as plt.

# %%
# Instructions
# 100 XP
# Create a plot so the shaded area shows the standard deviation instead of the confidence interval for the mean.

sns.relplot(x="model_year",y="mpg",data=df,kind="line",ci="sd")                 # This plot shows us the distribution of miles per gallon for all the cars in each year.
plt.show()

# %% [markdown]
# ### **Plotting subgroups in line plots**

# %% [markdown]
# Let's continue to look at the mpg dataset. We've seen that the average miles per gallon for cars has increased over time, but how has the average horsepower for cars changed over time? And does this trend differ by country of origin?

# %%
# Instructions 1/3
# 35 XP
# Use relplot() and the mpg DataFrame to create a line plot with "model_year" on the x-axis and "horsepower" on the y-axis. Turn off the confidence intervals on the plot.

display(df.head(5))

sns.relplot(x="model_year",y="horsepower",data=df,kind="line",ci=None)
plt.show()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# Instructions 2/3
# 35 XP
# Create different lines for each country of origin ("origin") that vary in both line style and color.

sns.relplot(x="model_year",y="horsepower",data=df,kind="line",ci=None,hue="origin",style="origin")
plt.show()

# %%
# Instructions 3/3
# 30 XP
# 3
# Add markers for each data point to the lines.
# Use the dashes parameter to use solid lines for all countries, while still allowing for different marker styles for each line.


sns.relplot(x="model_year",y="horsepower",data=df,kind="line",ci=None,hue="origin",style="origin",markers=True,dashes=False)
plt.show()

# %% [markdown]
# ## **Chapter 3: Visualizing a Categorical and a Quantitative Variable**

# %% [markdown]
# Categorical variables are present in nearly every dataset, but they are especially prominent in survey data. In this chapter, you will learn how to create and customize categorical plots such as box plots, bar plots, count plots, and point plots. Along the way, you will explore survey data from young people about their interests, students about their study habits, and adult men about their feelings about masculinity.

# %% [markdown]
# **Count plots and bar plots (VIDEO)**
#
# **Count plots**
#
# **Bar plots with percentages**
#
# **Customizing bar plots**
#
# **Box plots (VIDEO)**
#
# **Create and interpret a box plot**
#
# **Omitting outliers**
#
# **Adjusting the whiskers**
#
# **Point plots (VIDEO)**
#
# **Customizing point plots**
#
# **Point plots with subgroups**

# %% [markdown]
# ### **Count plots and bar plots(VIDEO)**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("masculinity.xlsx")
display(df)

sns.countplot(x="how_masculine",data=df)                                        # Graficos con countplot()
plt.show()
# Out:
#    participant_id    age   how_masculine how_important
# 0               1  18-34        somewhat      somewhat
# 1               2  18-34        somewhat      somewhat
# 2               3  18-34        somewhat      not_very
# 3               4  18-34  very_important      not_very
# 4               5  18-34  very_important          very

# %%
sns.catplot(x="how_masculine",data=df,kind="count")                             # Graficos con catplot()  y argumento kind="count"
plt.show()

# %%
orden = ["very_important","somewhat"]

sns.catplot(x="how_masculine",data=df,kind="count",order=orden)                 # Graficos con catplot()  y argumento order para elegir el orden de las categorias
plt.show()

# %%
df = sns.load_dataset("tips")
display(df)

sns.catplot(x="day",y="total_bill",data=df,kind="bar")                          #Grafico con catplot() con argumento kind="bar" para crear graficos de barras (muestra la media)
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x="day",y="total_bill",data=df,kind="bar",ci=None)                  #Grafico con catplot() con argumento kind="bar" para crear graficos de barras (muestra la media)
plt.show()                                                                      #Parametro ci=None para desactivar los intervalos de confianza para la media

# %%
sns.catplot(x="total_bill",y="day",data=df,kind="bar",ci=None)                  #Grafico con catplot() con argumento kind="bar" para crear graficos de barras (muestra la media)
plt.show()                                                                      #Parametro ci=None para desactivar los intervalos de confianza para la media

# %% [markdown]
# ### **Count plots**

# %% [markdown]
# In this exercise, we'll return to exploring our dataset that contains the responses to a survey sent out to young people. We might suspect that young people spend a lot of time on the internet, but how much do they report using the internet each day? Let's use a count plot to break down the number of survey responses in each category and then explore whether it changes based on age.
#
# As a reminder, to create a count plot, we'll use the catplot() function and specify the name of the categorical variable to count (x=), the pandas DataFrame to use (data=), and the type of plot (kind="count").
#
# Seaborn has been imported as sns and matplotlib.pyplot has been imported as plt.

# %%
# Instructions 1/3
# 35 XP
# Use sns.catplot() to create a count plot using the survey_data DataFrame with "Internet usage" on the x-axis.

import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

df = pd.read_excel("survey_data.xlsx")
display(df.head(5))

sns.catplot(x="Internet usage",data=df,kind="count")
plt.show()
# Out:
#    Music  Techno  Movies  History  Mathematics  Pets  Spiders  Loneliness  \
# 0    5.0     1.0     5.0      1.0          3.0   4.0      1.0         3.0
# 1    4.0     1.0     5.0      1.0          5.0   5.0      1.0         2.0
# 2    5.0     1.0     5.0      1.0          5.0   5.0      1.0         5.0
# 3    5.0     2.0     5.0      4.0          4.0   1.0      5.0         5.0
# 4    5.0     2.0     5.0      3.0          2.0   1.0      1.0         3.0
#
#    Parents' advice   Internet usage  Finances   Age  Siblings  Gender  \
# 0              4.0  few hours a day       3.0  20.0       1.0  female
# 1              2.0  few hours a day       3.0  19.0       2.0  female
# 2              3.0  few hours a day       2.0  20.0       2.0  female
# 3              2.0  most of the day       2.0  22.0       1.0  female
# 4              3.0  few hours a day       4.0  20.0       1.0  female
#
#   Village - town  Age Category
# 0        village  Less than 21
# 1           city  Less than 21
# 2           city  Less than 21
# 3           city           21+
# 4        village  Less than 21

# %%
# Instructions 2/3
# 35 XP
# Make the bars horizontal instead of vertical.

sns.catplot(y="Internet usage",data=df,kind="count")
plt.show()

# %%
# Instructions 3/3
# 30 XP
# Separate this plot into two side-by-side column subplots based on "Age Category", which separates respondents into those that are younger than 21 vs. 21 and older.

sns.catplot(y="Internet usage",data=df,kind="count",col="Age Category")
plt.show()

# %%
#Great job! It looks like most young people use the internet for a few hours every day, regardless of their age.

# %% [markdown]
# ### **Bar plots with percentages**

# %% [markdown]
# Let's continue exploring the responses to a survey sent out to young people. The variable "Interested in Math" is True if the person reported being interested or very interested in mathematics, and False otherwise. What percentage of young people report being interested in math, and does this vary based on gender? Let's use a bar plot to find out.
#
# As a reminder, we'll create a bar plot using the catplot() function, providing the name of categorical variable to put on the x-axis (x=), the name of the quantitative variable to summarize on the y-axis (y=), the pandas DataFrame to use (data=), and the type of categorical plot (kind="bar").
#
# Seaborn has been imported as sns and matplotlib.pyplot has been imported as plt.

# %%
# Instructions
# 100 XP
# Use the survey_data DataFrame and sns.catplot() to create a bar plot with "Gender" on the x-axis and "Interested in Math" on the y-axis.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("./survey_data_math.xlsx")
display(df.head(5))

sns.catplot(x="Gender",y="Interested in Math",data=df,kind="bar")
plt.show()
# Out:
#    Music  Techno  Movies  History  Mathematics  Pets  Spiders  Loneliness  \
# 0    5.0     1.0     5.0      1.0          3.0   4.0      1.0         3.0
# 1    4.0     1.0     5.0      1.0          5.0   5.0      1.0         2.0
# 2    5.0     1.0     5.0      1.0          5.0   5.0      1.0         5.0
# 3    5.0     2.0     5.0      4.0          4.0   1.0      5.0         5.0
# 4    5.0     2.0     5.0      3.0          2.0   1.0      1.0         3.0
#
#    Parents' advice   Internet usage  Finances   Age  Siblings  Gender  \
# 0              4.0  few hours a day       3.0  20.0       1.0  female
# 1              2.0  few hours a day       3.0  19.0       2.0  female
# 2              3.0  few hours a day       2.0  20.0       2.0  female
# 3              2.0  most of the day       2.0  22.0       1.0  female
# 4              3.0  few hours a day       4.0  20.0       1.0  female
#
#   Village - town  Interested in Math
# 0        village               False
# 1           city                True
# 2           city                True
# 3           city                True
# 4        village               False

# %% [markdown]
# Excellent. When the y-variable is True/False, bar plots will show the percentage of responses reporting True. This plot shows us that males report a much higher interest in math compared to females.

# %% [markdown]
# ### **Customizing bar plots**

# %% [markdown]
# In this exercise, we'll explore data from students in secondary school. The "study_time" variable records each student's reported weekly study time as one of the following categories: "<2 hours", "2 to 5 hours", "5 to 10 hours", or ">10 hours". Do students who report higher amounts of studying tend to get better final grades? Let's compare the average final grade among students in each category using a bar plot.
#
# Seaborn has been imported as sns and matplotlib.pyplot has been imported as plt

# %%
# Instructions 1/3
# 35 XP
# Use sns.catplot() to create a bar plot with "study_time" on the x-axis and final grade ("G3") on the y-axis, using the student_data DataFrame.

df = pd.read_excel("student_data.xlsx")

sns.catplot(x="study_time",y="G3",data=df,kind="bar")
plt.show()

# %%
# Instructions 2/3
# 35 XP
# Using the order parameter and the category_order list that is provided, rearrange the bars so that they are in order from lowest study time to highest.

category_order = ["<2 hours","2 to 5 hours","5 to 10 hours",">10 hours"]

sns.catplot(x="study_time",y="G3",data=df,kind="bar",order=category_order)
plt.show()

# %%
# Instructions 3/3
# 30 XP
# 3
# Update the plot so that it no longer displays confidence intervals.

sns.catplot(x="study_time",y="G3",data=df,kind="bar",order=category_order,ci=None)
plt.show()

# %% [markdown]
# Great work! Students in our sample who studied more have a slightly higher average grade, but it's not a strong relationship.

# %% [markdown]
# ### **Box plots(VIDEO)**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")
display(df.head(5))

sns.catplot(x="time",y="total_bill",data=df,kind="box")                         #Grafico de caja y bigotes para varias categorias
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x="time",y="total_bill",data=df,kind="box",order=["Dinner","Lunch"])           #Grafico de caja y bigotes para varias categorias. Argumento order para elegir el orden
plt.show()

# %%
sns.catplot(x="time",y="total_bill",data=df,kind="box",order=["Dinner","Lunch"],sym="")       #Grafico de caja y bigotes para varias categorias. Argumento sym="" para ocultar outliers
plt.show()

# %%
sns.catplot(x="time",y="total_bill",data=df,kind="box",order=["Dinner","Lunch"],whis=[0,100])     #Grafico de caja y bigotes para varias categorias. Argumento whis para definir los bigotes
plt.show()

# %% [markdown]
# ### **Create and interpret a box plot**

# %% [markdown]
# Let's continue using the student_data dataset. In an earlier exercise, we explored the relationship between studying and final grade by using a bar plot to compare the average final grade ("G3") among students in different categories of "study_time".
#
# In this exercise, we'll try using a box plot look at this relationship instead. As a reminder, to create a box plot you'll need to use the catplot() function and specify the name of the categorical variable to put on the x-axis (x=), the name of the quantitative variable to summarize on the y-axis (y=), the pandas DataFrame to use (data=), and the type of plot (kind="box").
#
# We have already imported matplotlib.pyplot as plt and seaborn as sns.

# %%
# Instructions 1/2
# 50 XP
# Use sns.catplot() and the student_data DataFrame to create a box plot with "study_time" on the x-axis and "G3" on the y-axis. Set the ordering of the categories to study_time_order.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plot

df = pd.read_excel("student_data.xlsx")
display(df.head(5))

study_time_order = ["<2 hours","2 to 5 hours","5 to 10 hours",">10 hours"]
sns.catplot(x="study_time",y="G3",data=df,kind="box",order=study_time_order)
plt.show()
# Out:
#    index school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  \
# 0      0     GP   F   18     GT3       A     4     4           2         0
# 1      1     GP   F   17     GT3       T     1     1           1         0
# 2      2     GP   F   15     LE3       T     1     1           1         3
# 3      3     GP   F   15     GT3       T     4     2           1         0
# 4      4     GP   F   16     GT3       T     3     3           1         0
#
#    ... goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0  ...     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1  ...     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# 2  ...     2    2    3      3       10   7   8  10     Urban   2 to 5 hours
# 3  ...     2    1    1      5        2  15  14  15     Urban  5 to 10 hours
# 4  ...     2    1    2      5        4   6  10  10     Urban   2 to 5 hours
#
# [5 rows x 30 columns]

# %%
# Instructions 2/2
# 50 XP
# Question
# Which of the following is a correct interpretation of this box plot?
# Possible Answers:
# The 75th percentile of grades is highest among students who study more than 10 hours a week.
# There are no outliers plotted for these box plots.
# The 5th percentile of grades among students studying less than 2 hours is 5.0.
# The median grade among students studying less than 2 hours is 10.0.  ✔✔✔✔✔✔✔

# %% [markdown]
# Correct! The line in the middle of each box represents the median.

# %% [markdown]
# ### **Omitting outliers**

# %% [markdown]
# Now let's use the student_data dataset to compare the distribution of final grades ("G3") between students who have internet access at home and those who don't. To do this, we'll use the "internet" variable, which is a binary (yes/no) indicator of whether the student has internet access at home.
#
# Since internet may be less accessible in rural areas, we'll add subgroups based on where the student lives. For this, we can use the "location" variable, which is an indicator of whether a student lives in an urban ("Urban") or rural ("Rural") location.
#
# Seaborn has already been imported as sns and matplotlib.pyplot has been imported as plt. As a reminder, you can omit outliers in box plots by setting the sym parameter equal to an empty string ("").

# %%
# Instructions
# 100 XP
# Use sns.catplot() to create a box plot with the student_data DataFrame, putting "internet" on the x-axis and "G3" on the y-axis.
# Add subgroups so each box plot is colored based on "location".
# Do not display the outliers.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("student_data.xlsx")
display(df.head(5))

sns.catplot(x="internet",y="G3",data=df,kind="box",hue="location",sym="")
plt.show()
# Out:
#    index school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  \
# 0      0     GP   F   18     GT3       A     4     4           2         0
# 1      1     GP   F   17     GT3       T     1     1           1         0
# 2      2     GP   F   15     LE3       T     1     1           1         3
# 3      3     GP   F   15     GT3       T     4     2           1         0
# 4      4     GP   F   16     GT3       T     3     3           1         0
#
#    ... goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0  ...     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1  ...     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# 2  ...     2    2    3      3       10   7   8  10     Urban   2 to 5 hours
# 3  ...     2    1    1      5        2  15  14  15     Urban  5 to 10 hours
# 4  ...     2    1    2      5        4   6  10  10     Urban   2 to 5 hours
#
# [5 rows x 30 columns]

# %% [markdown]
# Success! The median grades are quite similar between each group, but the spread of the distribution looks larger among students who have internet access.

# %% [markdown]
# ### **Adjusting the whiskers**

# %% [markdown]
# In the lesson we saw that there are multiple ways to define the whiskers in a box plot. In this set of exercises, we'll continue to use the student_data dataset to compare the distribution of final grades ("G3") between students who are in a romantic relationship and those that are not. We'll use the "romantic" variable, which is a yes/no indicator of whether the student is in a romantic relationship.
#
# Let's create a box plot to look at this relationship and try different ways to define the whiskers.
#
# We've already imported Seaborn as sns and matplotlib.pyplot as plt

# %%
# Instructions 1/3
# 35 XP
# 1
# Adjust the code to make the box plot whiskers to extend to 0.5 * IQR. Recall: the IQR is the interquartile range.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("student_data.xlsx")
display(df.head(5))

sns.catplot(x="romantic", y="G3", data=df, kind="box",whis=0.5)
plt.show()
# Out:
#    index school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  \
# 0      0     GP   F   18     GT3       A     4     4           2         0
# 1      1     GP   F   17     GT3       T     1     1           1         0
# 2      2     GP   F   15     LE3       T     1     1           1         3
# 3      3     GP   F   15     GT3       T     4     2           1         0
# 4      4     GP   F   16     GT3       T     3     3           1         0
#
#    ... goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0  ...     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1  ...     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# 2  ...     2    2    3      3       10   7   8  10     Urban   2 to 5 hours
# 3  ...     2    1    1      5        2  15  14  15     Urban  5 to 10 hours
# 4  ...     2    1    2      5        4   6  10  10     Urban   2 to 5 hours
#
# [5 rows x 30 columns]

# %%
# Instructions 2/3
# 35 XP
# Change the code to set the whiskers to extend to the 5th and 95th percentiles.

sns.catplot(x="romantic", y="G3", data=df, kind="box",whis=[5,95])
plt.show()

# %%
# Instructions 3/3
# 30 XP
# Change the code to set the whiskers to extend to the min and max values.

sns.catplot(x="romantic", y="G3", data=df, kind="box",whis=[0,100])
plt.show()

# %% [markdown]
# Fantastic! The median grade is the same between these two groups, but the max grade is higher among students who are not in a romantic relationship.

# %% [markdown]
# ### **Point plots(VIDEO)**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("masculinity_data.xlsx")
display(df.head(5))

sns.catplot(x="age",y="masculinity_important",data=df,hue="feel_masculine",kind="point")                               #Creación de un grafico de puntos
plt.show()
# Out:
#    participant_id      age   how_masculine how_important  \
# 0               1    18-34        somewhat      somewhat
# 1               2    35-64        somewhat      somewhat
# 2               3  65 & up        somewhat      not_very
# 3               4    18-34  very_important      not_very
# 4               5    35-64  very_important          very
#
#    masculinity_important  feel_masculine
# 0                   2.37            True
# 1                   2.62            True
# 2                   2.09            True
# 3                   2.38            True
# 4                   2.84            True

# %%
sns.catplot(x="age",y="masculinity_important",data=df,hue="feel_masculine",kind="point",join=False)                     ##Creación de un grafico de puntos sin unir los puntos
plt.show()

# %%
from numpy import median

df = sns.load_dataset("tips")
display(df.head(5))

sns.catplot(x="smoker",y="total_bill",data=df,kind="point",estimator=median)                           #Creación de un grafico de puntos mostrando la mediana
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x="smoker",y="total_bill",data=df,kind="point",estimator=median,capsize=0.2)                #Creación de un grafico de puntos mostrando la mediana
plt.show()

# %%
sns.catplot(x="smoker",y="total_bill",data=df,kind="point",estimator=median,ci=None)                #Creación de un grafico de puntos mostrando la mediana sin intervalo de confianza
plt.show()

# %% [markdown]
# ### **Customizing point plots**

# %% [markdown]
# Let's continue to look at data from students in secondary school, this time using a point plot to answer the question: does the quality of the student's family relationship influence the number of absences the student has in school? Here, we'll use the "famrel" variable, which describes the quality of a student's family relationship from 1 (very bad) to 5 (very good).
#
# As a reminder, to create a point plot, use the catplot() function and specify the name of the categorical variable to put on the x-axis (x=), the name of the quantitative variable to summarize on the y-axis (y=), the pandas DataFrame to use (data=), and the type of categorical plot (kind="point").
#
# We've already imported Seaborn as sns and matplotlib.pyplot as plt.

# %%
# Instructions 1/3
# 35 XP
# Use sns.catplot() and the student_data DataFrame to create a point plot with "famrel" on the x-axis and number of absences ("absences") on the y-axis.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("student_data.xlsx")
display(df.head(5))

sns.catplot(x="famrel",y="absences",data=df,kind="point")
plt.show()
# Out:
#    index school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  \
# 0      0     GP   F   18     GT3       A     4     4           2         0
# 1      1     GP   F   17     GT3       T     1     1           1         0
# 2      2     GP   F   15     LE3       T     1     1           1         3
# 3      3     GP   F   15     GT3       T     4     2           1         0
# 4      4     GP   F   16     GT3       T     3     3           1         0
#
#    ... goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0  ...     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1  ...     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# 2  ...     2    2    3      3       10   7   8  10     Urban   2 to 5 hours
# 3  ...     2    1    1      5        2  15  14  15     Urban  5 to 10 hours
# 4  ...     2    1    2      5        4   6  10  10     Urban   2 to 5 hours
#
# [5 rows x 30 columns]

# %%
# Instructions 2/3
# 35 XP
# Add "caps" to the end of the confidence intervals with size 0.2.

sns.catplot(x="famrel",y="absences",data=df,kind="point",capsize=0.2)
plt.show()

# %%
# Instructions 3/3
# 30 XP
# Remove the lines joining the points in each category.

sns.catplot(x="famrel",y="absences",data=df,kind="point",capsize=0.2,join=False)
plt.show()

# %% [markdown]
# Awesome! While the average number of absences is slightly smaller among students with higher-quality family relationships, the large confidence intervals tell us that we can't be sure there is an actual association here.

# %% [markdown]
# ### **Point plots with subgroups**

# %% [markdown]
# Let's continue exploring the dataset of students in secondary school. This time, we'll ask the question: is being in a romantic relationship associated with higher or lower school attendance? And does this association differ by which school the students attend? Let's find out using a point plot.
#
# We've already imported Seaborn as sns and matplotlib.pyplot as plt.

# %%
# Instructions 1/3
# 35 XP
# Use sns.catplot() and the student_data DataFrame to create a point plot with relationship status ("romantic") on the x-axis and number of absences ("absences") 
# on the y-axis. Color the points based on the school that they attend ("school").

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("student_data.xlsx")
display(df.head(5))

sns.catplot(x="romantic",y="absences",data=df,kind="point",hue="school")
plt.show()
# Out:
#    index school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  \
# 0      0     GP   F   18     GT3       A     4     4           2         0
# 1      1     GP   F   17     GT3       T     1     1           1         0
# 2      2     GP   F   15     LE3       T     1     1           1         3
# 3      3     GP   F   15     GT3       T     4     2           1         0
# 4      4     GP   F   16     GT3       T     3     3           1         0
#
#    ... goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0  ...     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1  ...     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# 2  ...     2    2    3      3       10   7   8  10     Urban   2 to 5 hours
# 3  ...     2    1    1      5        2  15  14  15     Urban  5 to 10 hours
# 4  ...     2    1    2      5        4   6  10  10     Urban   2 to 5 hours
#
# [5 rows x 30 columns]

# %%
# Instructions 2/3
# 35 XP
# Turn off the confidence intervals for the plot.

sns.catplot(x="romantic",y="absences",data=df,kind="point",hue="school",ci=None)
plt.show()

# %%
# Instructions 3/3
# 30 XP
# 3
# Since there may be outliers of students with many absences, use the median function that we've imported from numpy to display the median number of absences instead of the average.

from numpy import median

sns.catplot(x="romantic",y="absences",data=df,kind="point",hue="school",ci=None,estimator=median)
plt.show()

# %% [markdown]
# Good work! It looks like students in romantic relationships have a higher average and median number of absences in the GP school, but this association does not hold for the MS school.

# %% [markdown]
# ## **Chapter 4: Customizing Seaborn Plots**

# %% [markdown]
# In this final chapter, you will learn how to add informative plot titles and axis labels, which are one of the most important parts of any data visualization! You will also learn how to customize the style of your visualizations in order to more quickly orient your audience to the key takeaways. Then, you will put everything you have learned together for the final exercises of the course!

# %% [markdown]
# **Changing plot style and color(VIDEO)**
#
# **Changing style and palette**
#
# **Changing the scale**
#
# **Using a custom palette**
#
# **Adding titles and labels: Part 1(VIDEO)**
#
# **FacetGrids vs. AxesSubplots**
#
# **Adding a title to a FacetGrid object**
#
# **Adding titles and labels: Part 2(VIDEO)**
#
# **Adding a title and axis labels**
#
# **Rotating x-tick labels**
#
# **Putting it all together(VIDEO)**
#
# **Box plot with subgroups**
#
# **Bar plot with subgroups and subplots**
#
# **Well done! What's next?**

# %% [markdown]
# ### **Changing plot style and color(VIDEO)**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("masculinity_data.xlsx")
display(df.head(5))
# Out:
#    participant_id      age   how_masculine how_important  \
# 0               1    18-34        somewhat      somewhat
# 1               2    35-64        somewhat      somewhat
# 2               3  65 & up        somewhat      not_very
# 3               4    18-34  very_important      not_very
# 4               5    35-64  very_important          very
#
#    masculinity_important  feel_masculine
# 0                   2.37            True
# 1                   2.62            True
# 2                   2.09            True
# 3                   2.38            True
# 4                   2.84            True

# %%
sns.set_style("white")
sns.catplot(x="age",y="masculinity_important",data=df,kind="point",hue="feel_masculine")              #Grafico con el estilo por default
plt.show()

# %%
sns.set_style("whitegrid")
sns.catplot(x="age",y="masculinity_important",data=df,kind="point",hue="feel_masculine")              #Grafico con el estilo "whitegrid"
plt.show()

# %%
sns.set_style("ticks")
sns.catplot(x="age",y="masculinity_important",data=df,kind="point",hue="feel_masculine")              #Grafico con el estilo "ticks"
plt.show()

# %%
sns.set_style("darkgrid")
sns.catplot(x="age",y="masculinity_important",data=df,kind="point",hue="feel_masculine")              #Grafico con el estilo "darkgrid"
plt.show()

# %%
sns.set_palette("tab10")  
sns.catplot(x="how_masculine",data=df,kind="count")                             #Paleta de colores por defaul
plt.show()

# %%
sns.set_palette("PuRd")
sns.catplot(x="how_masculine",data=df,kind="count")                             #Paleta de colores "RdBu"
plt.show()

# %%
custom_palette = ["#FBB4AE","#CCEBC5"]
sns.set_palette(custom_palette)
sns.catplot(x="how_masculine",data=df,kind="count")                             #Paleta de colores customizada
plt.show()

# %%
sns.set_palette("tab10")                                                                              #Paleta de colores por defaul
sns.set_context("paper")                                                                              #Elegir la escala por default
sns.catplot(x="age",y="masculinity_important",data=df,kind="point",hue="feel_masculine")              
plt.show()

# %%
sns.set_palette("tab10")                                                                              #Paleta de colores por defaul
sns.set_context("notebook")                                                                           #Elegir la escala "notebook"
sns.catplot(x="age",y="masculinity_important",data=df,kind="point",hue="feel_masculine")              
plt.show()

# %%
sns.set_palette("tab10")                                                                              #Paleta de colores por defaul
sns.set_context("talk")                                                                               #Elegir la escala "talk"
sns.catplot(x="age",y="masculinity_important",data=df,kind="point",hue="feel_masculine")              
plt.show()

# %%
sns.set_palette("tab10")                                                                              #Paleta de colores por defaul
sns.set_context("poster")                                                                               #Elegir la escala "poster"
sns.catplot(x="age",y="masculinity_important",data=df,kind="point",hue="feel_masculine")              
plt.show()

# %% [markdown]
# ### **Changing style and palette**

# %% [markdown]
# Let's return to our dataset containing the results of a survey given to young people about their habits and preferences. We've provided the code to create a count plot of their responses to the question "How often do you listen to your parents' advice?". Now let's change the style and palette to make this plot easier to interpret.
#
# We've already imported Seaborn as sns and matplotlib.pyplot as plt.

# %%
# Instructions 1/3
# 35 XP
# Set the style to "whitegrid" to help the audience determine the number of responses in each category.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("survey_data_new.xlsx")
display(df.head(5))

category_order = ["Never", "Rarely", "Sometimes", "Often", "Always"]
sns.set_style("whitegrid")
sns.catplot(x="Parents Advice",data=df,kind="count",order=category_order)
plt.show()
sns.set_style("white")
# Out:
#    Music  Techno  Movies  History  Mathematics  Pets  Spiders  Loneliness  \
# 0    5.0     4.0     5.0      3.0          1.0   3.0      2.0         2.0
# 1    5.0     1.0     4.0      2.0          2.0   2.0      3.0         3.0
# 2    5.0     2.0     5.0      3.0          5.0   3.0      3.0         1.0
# 3    4.0     4.0     5.0      2.0          1.0   2.0      1.0         3.0
# 4    5.0     1.0     5.0      5.0          1.0   5.0      1.0         1.0
#
#   Parents Advice           Internet usage  Finances   Age  Siblings  Gender  \
# 0          Never          most of the day       3.0  21.0       1.0    male
# 1          Never          most of the day       1.0  22.0       1.0  female
# 2          Never          few hours a day       3.0  21.0       0.0  female
# 3          Never  less than an hour a day       1.0  30.0       1.0  female
# 4          Never  less than an hour a day       1.0  19.0       1.0  female
#
#   Village - town
# 0           city
# 1           city
# 2           city
# 3        village
# 4           city

# %%
# Instructions 2/3
# 35 XP
# Set the color palette to the sequential palette named "Purples".

sns.set_palette("Purples")
category_order = ["Never", "Rarely", "Sometimes", "Often", "Always"]
sns.catplot(x="Parents Advice",data=df,kind="count",order=category_order)
plt.show()
sns.set_palette("tab10")

# %%
# Instructions 3/3
# 30 XP
# 3
# Change the color palette to the diverging palette named "RdBu".

sns.set_palette("RdBu")
category_order = ["Never", "Rarely", "Sometimes", "Often", "Always"]
sns.catplot(x="Parents Advice",data=df,kind="count",order=category_order)
plt.show()
sns.set_palette("tab10")

# %% [markdown]
# Awesome work. This style and diverging color palette best highlights the difference between the number of young people who usually listen to their parents' advice versus those who don't.

# %% [markdown]
# ### **Changing the scale**

# %% [markdown]
# In this exercise, we'll continue to look at the dataset containing responses from a survey of young people. Does the percentage of people reporting that they feel lonely vary depending on how many siblings they have? Let's find out using a bar plot, while also exploring Seaborn's four different plot scales ("contexts").
#
# We've already imported Seaborn as sns and matplotlib.pyplot as plt.

# %%
# Instructions 1/4
# 25 XP
# Set the scale ("context") to "paper", which is the smallest of the scale options.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("survey_data.xlsx")
display(df.head(5))

sns.set_context("paper")
sns.catplot(x="Siblings", y="Loneliness", data=df, kind="bar")
sns.set_context("paper")                                                                              #Elegir la escala por default
# Out:
#    Music  Techno  Movies  History  Mathematics  Pets  Spiders  Loneliness  \
# 0    5.0     1.0     5.0      1.0          3.0   4.0      1.0         3.0
# 1    4.0     1.0     5.0      1.0          5.0   5.0      1.0         2.0
# 2    5.0     1.0     5.0      1.0          5.0   5.0      1.0         5.0
# 3    5.0     2.0     5.0      4.0          4.0   1.0      5.0         5.0
# 4    5.0     2.0     5.0      3.0          2.0   1.0      1.0         3.0
#
#    Parents' advice   Internet usage  Finances   Age  Siblings  Gender  \
# 0              4.0  few hours a day       3.0  20.0       1.0  female
# 1              2.0  few hours a day       3.0  19.0       2.0  female
# 2              3.0  few hours a day       2.0  20.0       2.0  female
# 3              2.0  most of the day       2.0  22.0       1.0  female
# 4              3.0  few hours a day       4.0  20.0       1.0  female
#
#   Village - town  Age Category
# 0        village  Less than 21
# 1           city  Less than 21
# 2           city  Less than 21
# 3           city           21+
# 4        village  Less than 21

# %%
# Instructions 2/4
# 25 XP
# Change the context to "notebook" to increase the scale.

sns.set_context("notebook")
sns.catplot(x="Siblings",y="Loneliness",data=df,kind="bar")
plt.show()
sns.set_context("paper")

# %%
# Instructions 3/4
# 25 XP
# Change the context to "talk" to increase the scale.

sns.set_context("talk")
sns.catplot(x="Siblings",y="Loneliness",data=df,kind="bar")
plt.show()
sns.set_context("paper")

# %%
# Instructions 4/4
# 25 XP
# Change the context to "poster", which is the largest scale available.

sns.set_context("poster")
sns.catplot(x="Siblings",y="Loneliness",data=df,kind="bar")
plt.show()
sns.set_context("paper")

# %% [markdown]
# Great job! Each context name gives Seaborn's suggestion on when to use a given plot scale (in a paper, in an iPython notebook, in a talk/presentation, or in a poster session).

# %% [markdown]
# ### **Using a custom palette**

# %% [markdown]
# So far, we've looked at several things in the dataset of survey responses from young people, including their internet usage, how often they listen to their parents, and how many of them report feeling lonely. However, one thing we haven't done is a basic summary of the type of people answering this survey, including their age and gender. Providing these basic summaries is always a good practice when dealing with an unfamiliar dataset.
#
# The code provided will create a box plot showing the distribution of ages for male versus female respondents. Let's adjust the code to customize the appearance, this time using a custom color palette.
#
# We've already imported Seaborn as sns and matplotlib.pyplot as plt.

# %%
# Instructions
# 100 XP
# Set the style to "darkgrid".
# Set a custom color palette with the hex color codes "#39A7D0" and "#36ADA4"

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("survey_data_new.xlsx")
display(df.head(5))

sns.set_style("darkgrid")
sns.set_palette(["#39A7D0", "#36ADA4"])
sns.catplot(x="Gender",y="Age",data=df,kind="box")
plt.show()
sns.set_palette("tab10")  
sns.set_style("white")
# Out:
#    Music  Techno  Movies  History  Mathematics  Pets  Spiders  Loneliness  \
# 0    5.0     4.0     5.0      3.0          1.0   3.0      2.0         2.0
# 1    5.0     1.0     4.0      2.0          2.0   2.0      3.0         3.0
# 2    5.0     2.0     5.0      3.0          5.0   3.0      3.0         1.0
# 3    4.0     4.0     5.0      2.0          1.0   2.0      1.0         3.0
# 4    5.0     1.0     5.0      5.0          1.0   5.0      1.0         1.0
#
#   Parents Advice           Internet usage  Finances   Age  Siblings  Gender  \
# 0          Never          most of the day       3.0  21.0       1.0    male
# 1          Never          most of the day       1.0  22.0       1.0  female
# 2          Never          few hours a day       3.0  21.0       0.0  female
# 3          Never  less than an hour a day       1.0  30.0       1.0  female
# 4          Never  less than an hour a day       1.0  19.0       1.0  female
#
#   Village - town
# 0           city
# 1           city
# 2           city
# 3        village
# 4           city

# %% [markdown]
# Good work! It looks like the median age is the same for males and females, but distribution of females skews younger than the males.

# %% [markdown]
# ### **Adding titles and labels: Part 1(VIDEO)**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("countries.xlsx")
display(df.head(5))

sns.catplot(x="Region",y="Birthrate",data=df,kind="box")                        #Grafico si modificar titulo o etiquetas
plt.show()
# Out:
#   Region  Birthrate
# 0   Asia         23
# 1   Asia         23
# 2   Asia         18
# 3   Asia         16
# 4   Asia         24

# %%
g = sns.catplot(x="Region",y="Birthrate",data=df,kind="box")                    #Asignar el grafico a una variable
g.fig.suptitle("Nuevo Titulo")                                                  #Asignar un titulo al grafico
plt.show()

# %%
g = sns.catplot(x="Region",y="Birthrate",data=df,kind="box")                    #Asignar el grafico a una variable
g.fig.suptitle("Nuevo Titulo",y=1.1)                                            #Asignar el titulo al grafico y modificar su posicion
plt.show()

# %% [markdown]
# ### **FacetGrids vs. AxesSubplots**

# %% [markdown]
# In the recent lesson, we learned that Seaborn plot functions create two different types of objects: FacetGrid objects and AxesSubplot objects. The method for adding a title to your plot will differ depending on the type of object it is.
#
# In the code provided, we've used relplot() with the miles per gallon dataset to create a scatter plot showing the relationship between a car's weight and its horsepower. This scatter plot is assigned to the variable name g. Let's identify which type of object it is.
#
# We've already imported Seaborn as sns and matplotlib.pyplot as plt.

# %%
# Instructions 1/2
# 50 XP
# Identify what type of object plot g is and assign it to the variable type_of_g.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("mpg")
display(df.head(5))

g = sns.relplot(x="weight",y="horsepower",data=df,kind="scatter")
print("El grafico es de tipo",type(g))
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino
# El grafico es de tipo <class 'seaborn.axisgrid.FacetGrid'>

# %%
# Instructions 2/2
# 50 XP
# Question
# We've just seen that sns.relplot() creates FacetGrid objects. Which other Seaborn function creates a FacetGrid object instead of an AxesSubplot object?

# Possible Answers

# sns.catplot()      ✔

# sns.scatterplot()

# sns.boxplot()

# sns.countplot()

# %% [markdown]
# Great job. catplot() supports creating subplots, so it creates a FacetGrid object.

# %% [markdown]
# ### **Adding a title to a FacetGrid object**

# %% [markdown]
# In the previous exercise, we used relplot() with the miles per gallon dataset to create a scatter plot showing the relationship between a car's weight and its horsepower. This created a FacetGrid object. Now that we know what type of object it is, let's add a title to this plot.
#
# We've already imported Seaborn as sns and matplotlib.pyplot as plt.

# %%
# Instructions
# 100 XP
# Add the following title to this plot: "Car Weight vs. Horsepower".

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("mpg")
display(df.head(5))

g = sns.relplot(x="weight",y="horsepower",data=df,kind="scatter")               #Asignar la grafica a la variable g
g.fig.suptitle("Car Weight vs. Horsepower")                                     #Agregar el titulo con g.fig.suptitle()
plt.show()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# Good work! It looks like a car's weight is positively correlated with its horsepower.

# %% [markdown]
# ### **Adding titles and labels: Part 2**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("countries.xlsx")
display(df.head(5))
# Out:
#   Region  Birthrate  Group
# 0   Asia         23      1
# 1   Asia         23      1
# 2   Asia         18      1
# 3   Asia         16      2
# 4   Asia         24      1

# %%
g = sns.catplot(x="Region",y="Birthrate",data=df,kind="box")                    #Asignar el grafico a una variable (FaceGrid)
g.fig.suptitle("New Title",y=1.2)                                               #Agregar un titulo con el comando g.fig.suptitle()
plt.show()

# %%
g = sns.boxplot(x="Region",y="Birthrate",data=df)                               #Asignar el grafico a una variable (AxesSubplot)
g.set_title("New Title",y=1.2)                                                  #Agregar un titulo con el comando g.set_title()
plt.show()

# %%
g = sns.catplot(x="Region",y="Birthrate",data=df,kind="box",col="Group")        #Asignar el grafico a la variable g (FaceGrid)
g.fig.suptitle("New Title",y=1.1)                                               #Agregar titulos con g.fig.suptitle()
g.set_titles("New Sub Title A","New Sub Title B")                               #Agregar titulo a cada subgrafica con g.set_title()
plt.show()

# %%
g = sns.catplot(x="Region",y="Birthrate",data=df,kind="box")
g.set(xlabel="Eje X",ylabel="Eje Y")                                            #Agregar nombres a los ejes
plt.show()

# %%
g = sns.catplot(x="Region",y="Birthrate",data=df,kind="box")
plt.xticks(rotation=90)                                                         #Rotar las etiquetas de eje X
plt.yticks(rotation=90)                                                         #Rotar las etiquetas de eje Y
plt.show()

# %% [markdown]
# ### **Adding a title and axis labels**

# %% [markdown]
# Let's continue to look at the miles per gallon dataset. This time we'll create a line plot to answer the question: How does the average miles per gallon achieved by cars change over time for each of the three places of origin? To improve the readability of this plot, we'll add a title and more informative axis labels.
#
# In the code provided, we create the line plot using the lineplot() function. Note that lineplot() does not support the creation of subplots, so it returns an AxesSubplot object instead of an FacetGrid object.
#
# We've already imported Seaborn as sns and matplotlib.pyplot as plt.

# %%
# Instructions 1/2
# 50 XP
# Add the following title to the plot: "Average MPG Over Time".

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("mpg_mean.xlsx")
display(df.head(5))

g = sns.lineplot(x="model_year", y="mpg_mean", data=df, hue="origin")
g.set_title("Average MPG Over Time")
plt.show()
# Out:
#    Unnamed: 0  model_year  origin  mpg_mean
# 0           0          70  europe    25.200
# 1           1          70   japan    25.500
# 2           2          70     usa    15.273
# 3           3          71  europe    28.750
# 4           4          71   japan    29.500

# %%
# Instructions 2/2
# 50 XP
# Label the x-axis as "Car Model Year" and the y-axis as "Average MPG"

g = sns.lineplot(x="model_year",y="mpg_mean",data=df,hue="origin")
g.set(xlabel="Car Model Year",ylabel="Average MPG")
plt.show()

# %% [markdown]
# Awesome. The average miles per gallon achieved is increasing over time for all three places of origin, but the USA is always lower than Europe and Japan.

# %% [markdown]
# ### **Rotating x-tick labels**

# %% [markdown]
# In this exercise, we'll continue looking at the miles per gallon dataset. In the code provided, we create a point plot that displays the average acceleration for cars in each of the three places of origin. Note that the "acceleration" variable is the time to accelerate from 0 to 60 miles per hour, in seconds. Higher values indicate slower acceleration.
#
# Let's use this plot to practice rotating the x-tick labels. Recall that the function to rotate x-tick labels is a standalone Matplotlib function and not a function applied to the plot object itself.
#
# We've already imported Seaborn as sns and matplotlib.pyplot as plt.

# %%
# Instructions
# 100 XP
# Rotate the x-tick labels 90 degrees.

df = sns.load_dataset("mpg")
display(df.head(5))

sns.catplot(x="origin", y="acceleration", data=df, kind="point", join=False, capsize=0.1)
plt.xticks(rotation=90)
plt.show()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ### **Putting it all together(VIDEO)**

# %%
# Resumen del capitulo

# %% [markdown]
# ### **Box plot with subgroups**

# %% [markdown]
# In this exercise, we'll look at the dataset containing responses from a survey given to young people. One of the questions asked of the young people was: "Are you interested in having pets?" Let's explore whether the distribution of ages of those answering "yes" tends to be higher or lower than those answering "no", controlling for gender.

# %%
# Instructions
# 100 XP
# Set the color palette to "Blues".
# Add subgroups to color the box plots based on "Interested in Pets".
# Set the title of the FacetGrid object g to "Age of Those Interested in Pets vs. Not".
# Make the plot display using a Matplotlib function.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("survey_data_pets.xlsx")
display(df.head(5))

sns.set_palette("Blues")
g = sns.catplot(x="Gender",y="Age", data=df,kind="box", hue="Interested in Pets")
g.fig.suptitle("Age of Those Interested in Pets vs. Not")
plt.show()
sns.set_palette("tab10")
# Out:
#    index  Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  \
# 0      0           0    5.0     1.0     5.0      1.0          3.0   4.0
# 1      1           1    4.0     1.0     5.0      1.0          5.0   5.0
# 2      2           2    5.0     1.0     5.0      1.0          5.0   5.0
# 3      3           3    5.0     2.0     5.0      4.0          4.0   1.0
# 4      4           4    5.0     2.0     5.0      3.0          2.0   1.0
#
#    Spiders  Loneliness  Parents' advice   Internet usage  Finances   Age  \
# 0      1.0         3.0              4.0  few hours a day       3.0  20.0
# 1      1.0         2.0              2.0  few hours a day       3.0  19.0
# 2      1.0         5.0              3.0  few hours a day       2.0  20.0
# 3      5.0         5.0              2.0  most of the day       2.0  22.0
# 4      1.0         3.0              3.0  few hours a day       4.0  20.0
#
#    Siblings  Gender Village - town Interested in Pets
# 0       1.0  female        village                Yes
# 1       2.0  female           city                Yes
# 2       2.0  female           city                Yes
# 3       1.0  female           city                 No
# 4       1.0  female        village                 No

# %% [markdown]
# Good job. After controlling for gender, it looks like the age distributions of people who are interested in pets are similar than those who aren't.

# %% [markdown]
# ### **Bar plot with subgroups and subplots**

# %% [markdown]
# In this exercise, we'll return to our young people survey dataset and investigate whether the proportion of people who like techno music ("Likes Techno") varies by their gender ("Gender") or where they live ("Village - town"). This exercise will give us an opportunity to practice the many things we've learned throughout this course!
#
# We've already imported Seaborn as sns and matplotlib.pyplot as plt.

# %%
# Instructions
# 100 XP
# Set the figure style to "dark".
# Adjust the bar plot code to add subplots based on "Gender", arranged in columns.
# Add the title "Percentage of Young People Who Like Techno" to this FacetGrid plot.
# Label the x-axis "Location of Residence" and y-axis "% Who Like Techno".


import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("survey_data_music.xlsx")
display(df.head(5))

sns.set_style("dark")
g = sns.catplot(x="Village - town", y="Likes Techno", data=df, kind="bar",col="Gender")
g.fig.suptitle("Percentage of Young People Who Like Techno",y=1.02)
g.set(xlabel="Location of Residence",  ylabel="% Who Like Techno")
plt.show()
sns.set_style("white")
# Out:
#    Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0           0    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1           1    4.0     1.0     5.0      1.0          5.0   5.0      1.0
# 2           2    5.0     1.0     5.0      1.0          5.0   5.0      1.0
# 3           3    5.0     2.0     5.0      4.0          4.0   1.0      5.0
# 4           4    5.0     2.0     5.0      3.0          2.0   1.0      1.0
#
#    Loneliness  Parents' advice   Internet usage  Finances   Age  Siblings  \
# 0         3.0              4.0  few hours a day       3.0  20.0       1.0
# 1         2.0              2.0  few hours a day       3.0  19.0       2.0
# 2         5.0              3.0  few hours a day       2.0  20.0       2.0
# 3         5.0              2.0  most of the day       2.0  22.0       1.0
# 4         3.0              3.0  few hours a day       4.0  20.0       1.0
#
#    Gender Village - town  Likes Techno
# 0  female        village         False
# 1  female           city         False
# 2  female           city         False
# 3  female           city         False
# 4  female        village         False

# %% [markdown]
# Amazing work! I hope you enjoyed this introductory course about Seaborn!

# %% [markdown]
# ### **Well done! What's next?(VIDEO)**
